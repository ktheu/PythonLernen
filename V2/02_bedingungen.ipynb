# %% [markdown]
# ### Bedingte Anweisungen

# %%
'''
Aufgabe 1:
Lies eine Zahl x ein
Falls x größer als 3:
    gib 'A' aus
gib 'Ende' aus

Beispieldialoge:

Bitte eine Zahl eingeben: 5
A
Ende

Bitte eine Zahl eingeben: 2
Ende    
'''
# your code

# %%
'''
Aufgabe 2:
Lies die Zahl x ein
Falls x > 100: Gib aus 'große Zahl'
sonst: Gib aus 'kleine Zahl'

Beispieldialoge:

Bitte Zahl eingeben: 56
kleine Zahl

Bitte Zahl eingeben: 120
große Zahl
'''
# your code

# %%
'''
Aufgabe 3:
Lies eine Zahl x ein
Falls x größer als 5:
    gib 'A' aus
sonst, falls x größer als 3 ist:
    gib 'B' aus
sonst:
    gib 'C' aus

Beispieldialoge:

Bitte eine Zahl eingeben: 7
A 

Bitte eine Zahl eingeben: 4
B   

Bitte eine Zahl eingeben: 3
C
'''
# your code

# %%
'''
Aufgabe 4:
Lies zwei Zahlen ein.
Gib aus, ob die erste Zahl größer als die zweite Zahl ist, oder umgekehrt oder ob beide Zahlen gleich sind.

Beispieldialoge:

Bitte zwei Zahlen eingeben: 50 88
Die zweite Zahl ist größer als die erste.

Bitte zwei Zahlen eingeben: 30 30
Die beiden Zahlen sind gleich.

Bitte zwei Zahlen eingeben: 10 2
Die erste Zahl ist größer als die zweite.
'''
# your code

# %%
''' 
Aufgabe 5:
Lies die Zahl winkel ein
Falls winkel < 90: Gib aus 'spitzer Winkel'
Falls winkel = 90: Gib aus 'rechter Winkel'
Falls winkel > 90: Gib aus 'stumpfer Winkel'

Beispieldialoge:

Bitte einen Winkel eingeben: 45
spitzer Winkel

Bitte einen Winkel eingeben: 90
rechter Winkel

Bitte einen Winkel eingeben: 120
stumpfer Winkel

''' 
# your code

# %%
''' 
Aufgabe 6:
Lies eine ganze Zahl ein und gib aus, ob sie gerade oder ungerade ist

Beispieldialoge:

Bitte eine ganze Zahl eingeben: 3
ungerade

Bitte eine ganze Zahl eingeben: 8
gerade
''' 
# your code

# %%
'''
Aufgabe 7:
Lies eine Zahl x ein
Falls x durch 2 teilbar: Gib aus '2 ist Teiler'
Falls x durch 3 teilbar: Gib aus '3 ist Teiler'
Falls x durch 5 teilbar: Gib aus '5 ist Teiler'
Falls x durch 7 teilbar: Gib aus '7 ist Teiler'
Falls x durch 11 teilbar: Gib aus '11 ist Teiler'

Beispieldialog:

Bitte eine Zahl eingeben: 3432
2 ist Teiler
3 ist Teiler
11 ist Teiler

Bitte eine Zahl eingeben: 480480
2 ist Teiler
3 ist Teiler
5 ist Teiler
7 ist Teiler
11 ist Teiler
''' 

# your code
