# %% [markdown]
# #### Zuweisungen und Rechenoperationen

# %%
''' 
Aufgabe 1:
Setze c auf 5
Setze d auf 7
Verdopple den Wert von c
e = c minus d
Gib das dreifache von e aus.

Erwartete Ausgabe: 9
'''
# your code

# %%
'''
Aufgabe 2:
Setze x auf 4
Setze y auf 7
Erhöhe x um 1
Erniedrige y um 2
Gib die Summe und das Produkt von x und y aus.

Erwartete Ausgabe:
10 25
'''
# your code

# %%
'''
Aufgabe 3:
Setze a auf 10 und b auf 12.
Erhöhe b um das Doppelte von a
Erhöhe den Wert von a um 1 und gib dann die Summe von a und b aus.

Erwartete Ausgabe:
43
'''
# your code

# %%
'''
Aufgabe 4:
setze x auf 104, y auf 7
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 
erniedrige x um 1
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 
erniedrige x um 1
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 

Erwartete Ausgabe:
14.86
14.71
14.57
'''
# your code

# %%
a = 1.5
b = 4.2
c = a * b
print(a*b)            # Ungenauigkeit
# Out:
# 6.300000000000001

# %%
d = round(c,1)        # Runden auf 1 Stelle hinter dem Komma
print(d)
# Out:
# 6.3

# %% [markdown]
# Dezimalzahlen nennen wir *floats* (floating point numbers), ganze Zahlen nennen wir *ints* (integers). Wenn wir zwei ints dividieren, entsteht immer ein float, auch wenn die Division aufgeht.

# %%
a = 6
b = 2
c = 6 / 2
print(c)               # 3 ist ein int, 3.0 ist ein float.
# Out:
# 3.0

# %% [markdown]
# Manchmal interessiert uns nur der ganzzahlige Anteil der Division und die Zahlen nach dem Dezimalpunkt spielen keine Rolle. Dafür nutzen wir den Operator für die ganzzahlige Division ```//```. Bei der ganzzahligen Division entsteht immer ein *int*.

# %%
a = 7
b = 3
print(a / b)
print(a // b)
# Out:
# 2.3333333333333335
# 2

# %%
'''
Aufgabe 3:
setze x auf 104, y auf 7
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 
erniedrige x um 1
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 
erniedrige x um 1
gib das Ergebnis x durch y aus, gerundet auf 2 Stellen 

Erwartete Ausgabe:
14.86
14.71
14.57
'''
# your code

# %% [markdown]
# #### Strings

# %% [markdown]
# #### Beispiel

# %%
'''
Setze s1 auf 'Rom'
Setze s2 auf 'Paris'
Setze a auf das 5-mal hintereinandergepappte s1
Setze b auf das 3-mal hintereinandergepappte s2
Pappe a dann b dann a zusammen und weise das Ergebnis der Variablen c zu
Gib c aus
'''
s1 = "Rom"
s2 = "Paris"
a = s1+s1+s1+s1+s1
b = s2+s2+s2
c = a+b+a
print(c)
# Out:
# RomRomRomRomRomParisParisParisRomRomRomRomRom

# %%
'''
Andere Lösung:
'''
s1 = "Rom"
s2 = "Paris"
c = 5*s1+3*s2+5*s1
print(c)
# Out:
# RomRomRomRomRomParisParisParisRomRomRomRomRom

# %%
'''
Aufgabe 4:
Setze s1 auf 'Hallo'
Setze s2 auf 'Welt'
Pappe s1 und ein Leerzeichen und s2 und ein Ausrufezeichen zusammen zur Variablen c
Gib c aus

Erwartete Ausgabe: 
Hallo Welt!
'''

# your code

# %%
'''
Aufgabe 5:
Setze x auf '.'
Setze y auf '+'
a = Aneinanderpappen von: 2 mal x, 1 mal y, 2 mal x  (a wird dann also '..+..')
Setze b auf 5 Wiederholungen von a
Gib b aus

Erwartete Ausgabe:
..+....+....+....+....+..
''' 
# your code

# %%
'''
Aufgabe 5:
Setze s1 auf 'Rom'
Setze s2 auf 'Paris'
Setze a auf das 5-mal hintereinander verkettete s1
Setze b auf das 3-mal hintereinander verkettete s2
Verkette a dann b dann a und weise das Ergebnis der Variablen c zu
Gib c aus

Erwartete Ausgabe:
RomRomRomRomRomParisParisParisRomRomRomRomRom
'''
#your code

# %%
'''
Aufgabe 6:
Setze s1 auf 'Hallo'
Setze s2 auf 'Welt'
Verkette s1 und ein Leerzeichen und s2 und ein Ausrufezeichen zusammen zur Variablen c
Gib c aus

Erwartete Ausgabe: 
Hallo Welt!
'''
# your code

# %%
'''
Aufgabe 7:
Setze x auf '.'
Setze y auf '+'
a = verkette 2 mal x, 1 mal y, 2 mal x  (a wird dann also '..+..')
Setze b auf 5 Wiederholungen von a
Gib b aus

Erwartete Ausgabe:
..+....+....+....+....+..
''' 
# your code

# %% [markdown]
# #### Input

# %%
'''
Aufgabe 8:
Lies ein Wort ein und gib es doppelt wieder aus.

Beispieldialog:

Bitte ein Wort eingeben: Hallo
HalloHallo
''' 
# your code

# %%
'''
Aufgabe 9:
Lies eine Zahl ein und gib das Doppelte der Zahl aus.

Beispieldialog:

Bitte eine Zahl eingeben: 5
10
''' 
# your code

# %%
'''
Aufgabe 10:
Lies nacheinander drei Zahlen ein und gib ihre Summe aus.

Beispieldialog:

Bitte die erste Zahl eingeben: 5
Bitte die zweite Zahl eingeben: 3
Bitte die dritte Zahl eingeben: 7
Die Summe ist 15
''' 
# your code

# %%
'''
Aufgabe 11:
Gib mit Leerzeichen getrennt drei Zahlen ein und gib die Summe aus.

Beispieldialog:

Bitte drei Zahlen eingeben: 5 3 7
Die Summe ist 15
''' 
# your code
