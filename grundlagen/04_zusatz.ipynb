# %%
''' Passwort
Schreibe ein Programm, das den Benutzer so lange nach einem Passwort fragt,
bis das richtige eingegeben wird.  
Das richtige Passwort lautet: "python123"

Beispieldialoge:

Bitte Passwort eingeben: hallo
Falsch!

Bitte Passwort eingeben: test
Falsch!

Bitte Passwort eingeben: python123
Richtig! Zugriff erlaubt.
'''
# your code

# %%
''' Zahlenraten
Schreibe ein Programm, das eine geheime Zahl (z. B. 7) vorgibt.
Der Benutzer darf solange raten, bis er die Zahl gefunden hat.

Wenn die Zahl zu klein ist, gib aus: "Zu klein!"
Wenn sie zu groß ist: "Zu groß!"
Wenn sie stimmt: "Richtig!" und das Programm endet.

Beispieldialoge:

Rate die Zahl:  3
Zu klein!
Rate die Zahl:  9
Zu groß!
Rate die Zahl:  7
Richtig!
'''
# your code

# %%
''' Bankautomat
Schreibe ein Programm, das einen Bankautomaten simuliert.

Der Startbetrag beträgt 100 €.
Der Benutzer kann in einer Schleife folgende Befehle eingeben:
- "einzahlen"
- "abheben"
- "ende"

Beim Einzahlen soll der Betrag zum Guthaben addiert werden.
Beim Abheben soll geprüft werden, ob genug Geld vorhanden ist.
Bei "ende" soll die Schleife mit break beendet werden.

Beispieldialog:

Guthaben: 100
Befehl (einzahlen/abheben/ende):  einzahlen
Betrag:  50
Neues Guthaben: 150

Befehl (einzahlen/abheben/ende):  abheben
Betrag:  70
Neues Guthaben: 80

Befehl (einzahlen/abheben/ende):  abheben
Betrag:  120
Nicht genug Guthaben!
Guthaben: 80

Befehl (einzahlen/abheben/ende):  ende
Programm beendet.
'''
# your code

# %%
''' PIN-Abfrage
Schreibe ein Programm, das den Benutzer nach einer vierstelligen PIN fragt.
Die richtige PIN lautet 1234.

Der Benutzer hat höchstens 3 Versuche.
Nach jedem falschen Versuch soll eine Fehlermeldung erscheinen.
Nach 3 falschen Versuchen wird das Konto gesperrt.

Beispieldialoge:

Bitte PIN eingeben:  1111
Falsch! Noch 2 Versuche.
Bitte PIN eingeben:  2222
Falsch! Noch 1 Versuch.
Bitte PIN eingeben:  1234
Richtig! Zugriff erlaubt.

oder

Bitte PIN eingeben:  1111
Falsch! Noch 2 Versuche.
Bitte PIN eingeben:  2222
Falsch! Noch 1 Versuch.
Bitte PIN eingeben:  3333
Konto gesperrt!
'''
# your code

# %%
''' Münzzähler
Schreibe ein Programm, das den Benutzer so lange nach Münzwerten fragt,
bis insgesamt mindestens 2 Euro eingegeben wurden.

Zulässige Werte sind: 10, 20, 50, 100 Cent.
Wenn der Benutzer einen anderen Wert eingibt, soll er übersprungen werden (continue).

Beispieldialoge:

Bitte Münzwert (in Cent) eingeben:  20
Gesamt: 20 Cent
Bitte Münzwert (in Cent) eingeben:  10
Gesamt: 30 Cent
Bitte Münzwert (in Cent) eingeben:  50
Gesamt: 80 Cent
Bitte Münzwert (in Cent) eingeben:  200
Ungültiger Wert!
Bitte Münzwert (in Cent) eingeben:  100
Gesamt: 180 Cent
Bitte Münzwert (in Cent) eingeben:  50
Ziel erreicht: 230 Cent
'''
# your code

# %%
''' Einkaufswagen
Schreibe ein Programm, das einen Einkaufswagen simuliert.

Starte mit einem leeren Gesamtpreis (0 €).
Frage den Benutzer wiederholt:
- "Artikelpreis (oder 0 zum Beenden):"

Wenn der Preis 0 eingegeben wird, soll die Schleife enden.
Am Ende soll die Gesamtsumme ausgegeben werden.

Beispieldialog:

Artikelpreis (oder 0 zum Beenden):  2.5
Artikelpreis (oder 0 zum Beenden):  1.2
Artikelpreis (oder 0 zum Beenden):  0
Gesamtsumme: 3.7 €
'''
# your code
