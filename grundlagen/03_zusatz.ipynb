# %% [markdown]
# ### 03_Zusatzaufgaben

# %%
''' Geschwindigkeitskontrolle
Ein Auto fährt in einer 50er-Zone. Schreibe ein Programm, das die gefahrene Geschwindigkeit
abfragt (int) und ausgibt, ob der Fahrer sich an die Regeln hält, zu schnell oder viel zu schnell ist.

Regeln:
- Bis 50 km/h -> "Alles in Ordnung."
- 51–70 km/h -> "Achtung, zu schnell!"
- Über 70 km/h -> "Viel zu schnell! Das gibt Ärger."

Beispieldialoge:

Bitte die gefahrene Geschwindigkeit eingeben:  45
Alles in Ordnung.

Bitte die gefahrene Geschwindigkeit eingeben:  63
Achtung, zu schnell!

Bitte die gefahrene Geschwindigkeit eingeben:  92
Viel zu schnell! Das gibt Ärger.
'''
# your code

# %%
''' Dreizahlentest
Schreibe ein Programm, das drei ganze Zahlen einliest.
Gib aus, ob alle drei gleich groß sind, ob zwei gleich groß sind oder ob alle verschieden sind.

Beispieldialoge:

Zahl 1:  4
Zahl 2:  4
Zahl 3:  4
Alle drei Zahlen sind gleich.

Zahl 1:  5
Zahl 2:  2
Zahl 3:  5
Zwei Zahlen sind gleich.

Zahl 1:  1
Zahl 2:  2
Zahl 3:  3
Alle Zahlen sind verschieden.
'''
# your code

# %%
''' Dreiecke
Dreiecke kann man mittels Winkeln klassifizieren.

Ein rechtwinkliges Dreicke hat einen Winkel von 90°
Ein stumpfes Dreieck hat einen Winkel, der größer als 90° ist
Bei einem spitzen Dreick sind alle Winkel kleiner als 90°

Schreibe ein Programm, das den Anwender nach drei Winkeln befragt (ints). 
Prüfe zunächst, ob die eingebenen Winkel korrekt sind, also sich zu 180 summieren. 
Klassifiziere dann das Rechteck als rechtwinklig, stumpf oder spitz.

Beispieldialoge:

Bitte den ersten Winkel eingeben:  10
Bitte den zweiten Winkel eingeben:  80
Bitte den dritten Winkel eingeben:  90
Die Winkel gehören zu einem rechtwinkliges Dreieck.

Bitte den ersten Winkel eingeben:  200
Bitte den zweiten Winkel eingeben:  -10
Bitte den dritten Winkel eingeben:  -10
Winkel kleiner 0 sind nicht zulässig.

Bitte den ersten Winkel eingeben:  60
Bitte den zweiten Winkel eingeben:  80
Bitte den dritten Winkel eingeben:  40
Die Winkel gehören zu einem spitzen Dreieck.

Bitte den ersten Winkel eingeben:  100
Bitte den zweiten Winkel eingeben:  30
Bitte den dritten Winkel eingeben:  50
Die Winkel gehören zu einem stumpfen Dreieck.
'''
# your code

# %%
''' Schaltjahr
Ein Jahr ist ein Schaltjahr, wenn es durch 4 teilbar ist,
aber nicht durch 100 — außer es ist durch 400 teilbar.

Schreibe ein Programm, das prüft, ob ein Jahr ein Schaltjahr ist.

Beispieldialoge:

Bitte ein Jahr eingeben:  2020
2020 ist ein Schaltjahr.

Bitte ein Jahr eingeben:  1900
1900 ist kein Schaltjahr.

Bitte ein Jahr eingeben:  2000
2000 ist ein Schaltjahr.
'''
# your code

# %%
''' Notendurchschnitt
Schreibe ein Programm, das drei Noten (zwischen 1 und 6) einliest.
Berechne den Durchschnitt und gib eine Bewertung aus:

- Durchschnitt < 2.0 -> "Sehr gut!"
- Durchschnitt < 3.0 -> "Gut."
- Durchschnitt < 4.0 -> "Befriedigend."
- Durchschnitt < 5.0 -> "Ausreichend."
- Sonst -> "Nicht bestanden."

Beispieldialoge:

Erste Note:  1
Zweite Note:  2
Dritte Note:  3
Durchschnitt: 2.0 -> Gut.

Erste Note:  5
Zweite Note:  4
Dritte Note:  6
Durchschnitt: 5.0 -> Nicht bestanden.
'''
# your code

# %%
''' Taschenrechner
Schreibe ein Programm, das zwei ganze Zahlen und einen Rechenoperator (+, -, *, /) einliest.
Führe die passende Berechnung aus.
Falls der Operator ungültig ist, gib eine Fehlermeldung aus.
Achte auch auf eine mögliche Division durch 0.

Beispieldialoge:

Erste Zahl:  10
Zweite Zahl:  2
Operator (+, -, *, /):  /
Ergebnis: 5.0

Erste Zahl:  7
Zweite Zahl:  0
Operator (+, -, *, /):  /
Fehler: Division durch 0 ist nicht erlaubt.

Erste Zahl:  4
Zweite Zahl:  5
Operator (+, -, *, /):  x
Unbekannter Operator!
'''
# your code

# %%
''' Achterbahn
In einem Freizeitpark darf man eine Achterbahn nur fahren, wenn man
mindestens 140 cm groß ist. Kinder zwischen 120 und 139 cm dürfen
nur in Begleitung eines Erwachsenen mitfahren. Darunter ist Fahren verboten.

Schreibe ein Programm, das Größe (in cm) und Begleitung (ja/nein) abfragt.

Beispieldialoge:

Wie groß bist du (in cm)?  150
Bist du in Begleitung eines Erwachsenen (ja/nein)?  nein
Du darfst fahren.

Wie groß bist du (in cm)?  130
Bist du in Begleitung eines Erwachsenen (ja/nein)?  ja
Du darfst fahren (mit Begleitung).

Wie groß bist du (in cm)?  130
Bist du in Begleitung eines Erwachsenen (ja/nein)?  nein
Du darfst nicht fahren.

Wie groß bist du (in cm)?  110
Bist du in Begleitung eines Erwachsenen (ja/nein)?  ja
Du darfst nicht fahren.
'''
# your code

# %%
''' Monatslänge
Schreibe ein Programm, das eine Monatszahl (1–12) und ein Jahr einliest.
Gib aus, wie viele Tage der Monat hat.

Februar hat 28 Tage, in einem Schaltjahr 29 Tage.
Verwende dazu die Schaltjahrregel:
Ein Jahr ist ein Schaltjahr, wenn es durch 4 teilbar ist,
aber nicht durch 100 – außer es ist durch 400 teilbar.

Beispieldialoge:

Bitte den Monat eingeben (1–12):  1
Bitte das Jahr eingeben:  2024
Der Monat 1 hat 31 Tage.

Bitte den Monat eingeben (1–12):  2
Bitte das Jahr eingeben:  2024
Der Monat 2 hat 29 Tage.

Bitte den Monat eingeben (1–12):  2
Bitte das Jahr eingeben:  1900
Der Monat 2 hat 28 Tage.

Bitte den Monat eingeben (1–12):  11
Bitte das Jahr eingeben:  2023
Der Monat 11 hat 30 Tage.
'''
# your code
